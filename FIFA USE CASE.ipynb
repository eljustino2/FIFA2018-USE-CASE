# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
# %matplotlib inline

df = pd.read_csv('Documents/FullData.csv')
df.head(7)
# Out:
#                  Name Nationality National_Position  National_Kit  \
# 0   Cristiano Ronaldo    Portugal                LS           7.0
# 1        Lionel Messi   Argentina                RW          10.0
# 2              Neymar      Brazil                LW          10.0
# 3         Luis Suárez     Uruguay                LS           9.0
# 4        Manuel Neuer     Germany                GK           1.0
# 5              De Gea       Spain                GK           1.0
# 6  Robert Lewandowski      Poland                LS           9.0
#
#              Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  \
# 0     Real Madrid            LW       7.0   07/01/2009           2021.0
# 1    FC Barcelona            RW      10.0   07/01/2004           2018.0
# 2    FC Barcelona            LW      11.0   07/01/2013           2021.0
# 3    FC Barcelona            ST       9.0   07/11/2014           2021.0
# 4       FC Bayern            GK       1.0   07/01/2011           2021.0
# ...

# %%
p=pd.read_csv(r"C:\Users\INNOVATION\Documents\FullData.csv")

# %%
p.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#    ... Long_Shots Curve Freekick_Accuracy Penalties  Volleys GK_Positioning  \
# ...

# %%
del df['National_Kit']
df.head()
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
# 3        Luis Suárez     Uruguay                LS  FC Barcelona
# 4       Manuel Neuer     Germany                GK     FC Bayern
#
#   Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  Height  ...  \
# 0            LW       7.0   07/01/2009           2021.0      94  185 cm  ...
# 1            RW      10.0   07/01/2004           2018.0      93  170 cm  ...
# 2            LW      11.0   07/01/2013           2021.0      92  174 cm  ...
# 3            ST       9.0   07/11/2014           2021.0      92  182 cm  ...
# 4            GK       1.0   07/01/2011           2021.0      92  193 cm  ...
#
#   Long_Shots Curve Freekick_Accuracy  Penalties Volleys GK_Positioning  \
# ...

# %%
plt.rcParams['figure.figsize']=(8,6)

# %%
plt.Figure(figsize=(15,32))
sns.countplot(y=df.Nationality,palette='Set2')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_17180\1848202749.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df.Nationality,palette='Set2')
# <Axes: xlabel='count', ylabel='Nationality'>

# %%
plt.Figure(figsize=(15,6))
sns.countplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ## BEST GOAL KEEPER

# %%
#weights
a=0.5
b=1
c=2
d=3

# %%
#Goalkeeping Characters
df['gk_shot_stopper']=(b*df.Reactions + b*df.Composure + a*df.Speed + a*df.Strength + c*df.Jumping + b*df.GK_Positioning + c*df.GK_Diving + d*df.GK_Reflexes + b*df.GK_Handling)/(2*a + 4*b + 2*c + 1*d)
df['gk_sweeper']=(b*df.Reactions + b*df.Composure + b*df.Speed + a*df.Short_Pass + a*df.Long_Pass + b*df.Jumping + b*df.GK_Positioning + b*df.GK_Diving + d*df.GK_Reflexes + b*df.GK_Handling + d*df.GK_Kicking + c*df.Vision)/(2*a + 7*b + 1*c + 2*d)

# %%
plt.figure(figsize=(8,6))
# Generate sequential data and plot
sd1=df.sort_values('gk_shot_stopper',ascending=False)[:5]
x1=np.array(list(sd1['Name']))
y1=np.array(list(sd1['gk_shot_stopper']))

sns.barplot(x=x1,y=y1,palette='colorblind')
plt.ylabel('Shot Stopping Score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_17180\19185905.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x1,y=y1,palette='colorblind')
# Text(0, 0.5, 'Shot Stopping Score')

# %%
plt.figure(figsize=(10,6))
# Generate sequential data and plot
sd1=df.sort_values('gk_sweeper',ascending=False)[:5]
x2=np.array(list(sd1['Name']))
y2=np.array(list(sd1['gk_sweeper']))

sns.barplot(x=x2,y=y2,palette='colorblind')
plt.ylabel('Sweeping Score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_17180\1733848212.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x2,y=y2,palette='colorblind')
# Text(0, 0.5, 'Sweeping Score')

# %% [markdown]
# # 4 BEST DEFENDERS

# %%
df['df_centre_backs']=(d*df.Reactions + c*df.Interceptions + d*df.Sliding_Tackle + d*df.Standing_Tackle + b*df.Vision + b*df.Composure + b*df.Crossing + a*df.Short_Pass + b*df.Long_Pass + c*df.Acceleration + b*df.Speed + d*df.Stamina + d*df.Jumping + d*df.Heading + b*df.Long_Shots + d*df.Marking + c*df.Aggression)/(1*a + 7*d + 3*c + 6*b)
df['df_wing_backs']=(b*df.Ball_Control + a*df.Dribbling + d*df.Sliding_Tackle + d*df.Standing_Tackle + a*df.Attacking_Position + c*df.Vision + c*df.Crossing + b*df.Short_Pass + c*df.Long_Pass + d*df.Acceleration + d*df.Speed + c*df.Stamina + a*df.Marking + a*df.Finishing)/(4*a + 4*d + 4*c + 2*b)

# %%
# LCB

plt.figure(figsize=(15,6))
sd=df[(df['Club_Position']=='LCB')].sort_values('df_centre_backs', ascending=False)[:5]
x2=np.array(list(sd['Name']))
y2=np.array(list(sd['df_centre_backs']))
sns.barplot(x=x2,y=y2,palette=sns.color_palette('Blues_d'))
plt.ylabel('LCB Score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\2060459346.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x2,y=y2,palette=sns.color_palette('Blues_d'))
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\2060459346.py:5: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(x=x2,y=y2,palette=sns.color_palette('Blues_d'))
# Text(0, 0.5, 'LCB Score')

# %%
# RCB
plt.figure(figsize=(15,6))
sd=df[(df['Club_Position']=='RCB')].sort_values('df_centre_backs', ascending=False)[:5]
x2=np.array(list(sd['Name']))
y2=np.array(list(sd['df_centre_backs']))
sns.barplot(x=x2,y=y2,palette=sns.color_palette('Blues_d'))
plt.ylabel('RCB Score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_1260\242534708.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x2,y=y2,palette=sns.color_palette('Blues_d'))
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_1260\242534708.py:6: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(x=x2,y=y2,palette=sns.color_palette('Blues_d'))
# Text(0, 0.5, 'RCB Score')

# %%
# LWB OR LB
plt.figure(figsize=(15,6))
sd=df[(df['Club_Position']=='LWB')|(df['Club_Position']=='LB')].sort_values('df_wing_backs', ascending=False)[:5]
x3=np.array(list(sd['Name']))
y3=np.array(list(sd['df_wing_backs']))
sns.barplot(x=x3,y=y3,palette=sns.color_palette('Blues_d'))
plt.ylabel('LB Score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\2202235280.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x3,y=y3,palette=sns.color_palette('Blues_d'))
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\2202235280.py:6: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(x=x3,y=y3,palette=sns.color_palette('Blues_d'))
# Text(0, 0.5, 'LB Score')

# %%
#RWB OR RB
plt.figure(figsize=(15,6))
sd=df[(df['Club_Position']=='RWB')|(df['Club_Position']=='RB')].sort_values('df_wing_backs', ascending=False)[:5]
x4=np.array(list(sd['Name']))
y4=np.array(list(sd['df_wing_backs']))
sns.barplot(x=x4,y=y4,palette=sns.color_palette('Blues_d'))
plt.ylabel('RB Score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\4048815290.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x4,y=y4,palette=sns.color_palette('Blues_d'))
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\4048815290.py:6: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(x=x4,y=y4,palette=sns.color_palette('Blues_d'))
# Text(0, 0.5, 'RB Score')

# %% [markdown]
# # BEST 3 MIDFIELDERS

# %%
# LCM RCM AM
df['mf_controller']=(b*df.Weak_foot + d*df.Ball_Control + a*df.Dribbling + a*df.Marking + a*df.Reactions + c*df.Vision + c*df.Composure + d*df.Short_Pass + d*df.Long_Pass)/(3*a + 3*d + 2*c + 1*b)
df['mf_playmaker']=(d*df.Ball_Control + d*df.Dribbling + a*df.Marking + d*df.Reactions + d*df.Vision + c*df.Attacking_Position + c*df.Crossing + d*df.Short_Pass + c*df.Long_Pass + c*df.Curve + b*df.Long_Shots + c*df.Freekick_Accuracy)/(1*a + 1*b + 5*c + 5*d)
df['mf_beast']=(d*df.Agility + c*df.Balance + b*df.Jumping + c*df.Strength + d*df.Stamina + a*df.Speed + c*df.Acceleration + d*df.Short_Pass + c*df.Aggression + d*df.Reactions + b*df.Standing_Tackle + b*df.Sliding_Tackle + b*df.Marking + b*df.Interceptions)/(1*a + 5*b + 4*c + 4*d )

# %%
# Controller

plt.figure(figsize=(15,6))
sd=df[(df['Club_Position']=='LCM')|(df['Club_Position']=='LM')].sort_values('mf_controller', ascending=False)[:5]
x1=np.array(list(sd['Name']))
y1=np.array(list(sd['mf_controller']))
sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(145,280,s=85,l=25,n=5))
plt.ylabel('Controller score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\2899109883.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(145,280,s=85,l=25,n=5))
# Text(0, 0.5, 'Controller score')

# %%
# playmaker AM

plt.figure(figsize=(15,6))
sd=df[(df['Club_Position']=='CAM')|(df['Club_Position']=='LAM')|(df['Club_Position']=='RAM')].sort_values('mf_playmaker', ascending=False)[:5]
x1=np.array(list(sd['Name']))
y1=np.array(list(sd['mf_playmaker']))
sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(145,280,s=85,l=25,n=5))
plt.ylabel('Playmaker score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\686765834.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(145,280,s=85,l=25,n=5))
# Text(0, 0.5, 'Playmaker score')

# %%
# BEAST CDM RCM
plt.figure(figsize=(15,6))
sd=df[(df['Club_Position']=='RCM')|(df['Club_Position']=='RM')|(df['Club_Position']=='CDM')].sort_values('mf_beast', ascending=False)[:5]
x1=np.array(list(sd['Name']))
y1=np.array(list(sd['mf_beast']))
sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(145,280,s=85,l=25,n=5))
plt.ylabel('beast score')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_10788\375209094.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(145,280,s=85,l=25,n=5))
# Text(0, 0.5, 'beast score')

# %% [markdown]
# ## BEST 3 ATTACKERS

# %%
# ATTACKERS
df['att_wing']=(c*df.Weak_foot + c*df.Ball_Control + c*df.Dribbling + c*df.Speed + d*df.Acceleration + b*df.Vision + c*df.Crossing + b*df.Short_Pass + b*df.Long_Pass + b*df.Aggression + b*df.Agility + a*df.Curve + c*df.Long_Shots + b*df.Freekick_Accuracy + d*df.Finishing + c*df.Attacking_Position)/(1*a + 6*b + 7*c + 2*d)
df['att_striker']=(b*df.Weak_foot + b*df.Ball_Control + a*df.Vision + b*df.Aggression + b*df.Agility + a*df.Curve + a*df.Long_Shots + d*df.Balance + d*df.Finishing + d*df.Heading + c*df.Jumping + c*df.Dribbling)/(3*a + 4*b + 2*c + 3*d)

# %%
#plot Lw
plt.figure(figsize=(15,6))

ss=df[(df['Club_Position']=='LW')|(df['Club_Position']=='LM')|(df['Club_Position']=='LS')].sort_values('att_wing', ascending=False)[:5]
x1=np.array(list(ss['Name']))
y1=np.array(list(ss['att_wing']))
sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(255,133,l=60,n=5,center='dark'))
plt.ylabel('Left Wing')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_8332\1514569167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(255,133,l=60,n=5,center='dark'))
# Text(0, 0.5, 'Left Wing')

# %%
#plot Rw
plt.figure(figsize=(15,6))

ss=df[(df['Club_Position']=='RW')|(df['Club_Position']=='RM')|(df['Club_Position']=='RS')].sort_values('att_wing', ascending=False)[:5]
x1=np.array(list(ss['Name']))
y1=np.array(list(ss['att_wing']))
sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(255,133,l=60,n=5,center='dark'))
plt.ylabel('Right Wing')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_8332\507028601.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(255,133,l=60,n=5,center='dark'))
# Text(0, 0.5, 'Right Wing')

# %%
#plot striker
plt.figure(figsize=(15,6))

ss=df[(df['Club_Position']=='ST')|(df['Club_Position']=='SS')|(df['Club_Position']=='CF')|(df['Club_Position']=='RS')|(df['Club_Position']=='LS')].sort_values('att_striker', ascending=False)[:5]
x1=np.array(list(ss['Name']))
y1=np.array(list(ss['att_striker']))
sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(255,133,l=60,n=5,center='dark'))
plt.ylabel('Striker')
# Out:
# C:\Users\INNOVATION\AppData\Local\Temp\ipykernel_8332\1063904521.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x1,y=y1,palette=sns.diverging_palette(255,133,l=60,n=5,center='dark'))
# Text(0, 0.5, 'Striker')
